# %%
import pandas as pd

movie_df = pd.read_csv("ml-20m/movies.csv")
ratings_df = pd.read_csv("ml-20m/ratings.csv")
genome_score = pd.read_csv("ml-20m/genome-scores.csv")
genome_tag = pd.read_csv("ml-20m/genome-tags.csv")
links_df = pd.read_csv("ml-20m/links.csv")

# %%
movies_rating_df = pd.merge(movie_df, ratings_df, how="left", left_on='movieId', right_on='movieId')
movies_rating_df = movies_rating_df.reset_index()
back_uo = movies_rating_df.copy(deep=True)
movies_rating_df.set_index(["movieId","title", "genres"], inplace=True)
back_uo
# Out:
#              index  movieId                          title  \
# 0                0        1               Toy Story (1995)
# 1                1        1               Toy Story (1995)
# 2                2        1               Toy Story (1995)
# 3                3        1               Toy Story (1995)
# 4                4        1               Toy Story (1995)
# ...            ...      ...                            ...
# 20000792  20000792   131254   Kein Bund für's Leben (2007)
# 20000793  20000793   131256  Feuer, Eis & Dosenbier (2002)
# 20000794  20000794   131258             The Pirates (2014)
# 20000795  20000795   131260            Rentun Ruusu (2001)
# 20000796  20000796   131262               Innocence (2014)
#
#                                                genres    userId  rating  \
# 0         Adventure|Animation|Children|Comedy|Fantasy       3.0     4.0
# 1         Adventure|Animation|Children|Comedy|Fantasy       6.0     5.0
# ...

# %%
# back_uo.set_index(["userId"], inplace=True)
ratings_sorted_df = back_uo.sort_values(by=['userId', 'timestamp'])

# %%
ratings_sorted_df
# Out:
#              index  movieId                                         title  \
# 5200644    5200644      924                  2001: A Space Odyssey (1968)
# 5136062    5136062      919                      Wizard of Oz, The (1939)
# 11307285  11307285     2683  Austin Powers: The Spy Who Shagged Me (1999)
# 8198569    8198569     1584                                Contact (1997)
# 5651449    5651449     1079                   Fish Called Wanda, A (1988)
# ...            ...      ...                                           ...
# 20000005  20000005   128886                        Love at the Top (1974)
# 20000122  20000122   129201                         The Time Being (2012)
# 20000256  20000256   129443                        Thank You a Lot (2014)
# 20000369  20000369   129820                            Spare Parts (2015)
# 20000443  20000443   130040                                     Mo (1983)
#
#                                       genres  userId  rating     timestamp
# ...

# %%
display_df = ratings_sorted_df.copy()

# Set 'userId' as the first level of the index.
# This visually groups the rows by user.
display_df = display_df.set_index(['userId', display_df.index])

# %%
display_df.loc[display_df.index != 1.0]
# Out:
#                       index  movieId  \
# userId
# 1.0      5200644    5200644      924
#          5136062    5136062      919
#          11307285  11307285     2683
#          8198569    8198569     1584
#          5651449    5651449     1079
# ...                     ...      ...
# NaN      20000005  20000005   128886
#          20000122  20000122   129201
#          20000256  20000256   129443
#          20000369  20000369   129820
#          20000443  20000443   130040
#
#                                                           title  \
# userId
# 1.0      5200644                   2001: A Space Odyssey (1968)
#          5136062                       Wizard of Oz, The (1939)
#          11307285  Austin Powers: The Spy Who Shagged Me (1999)
#          8198569                                 Contact (1997)
#          5651449                    Fish Called Wanda, A (1988)
# ...                                                         ...
# ...

# %%
# ratings_sorted_df.set_index(["userId"], inplace=True)
ratings_sorted_df
# Out:
#            index  movieId                                         title  \
# userId
# 1.0      5200644      924                  2001: A Space Odyssey (1968)
# 1.0      5136062      919                      Wizard of Oz, The (1939)
# 1.0     11307285     2683  Austin Powers: The Spy Who Shagged Me (1999)
# 1.0      8198569     1584                                Contact (1997)
# 1.0      5651449     1079                   Fish Called Wanda, A (1988)
# ...          ...      ...                                           ...
# NaN     20000005   128886                        Love at the Top (1974)
# NaN     20000122   129201                         The Time Being (2012)
# NaN     20000256   129443                        Thank You a Lot (2014)
# NaN     20000369   129820                            Spare Parts (2015)
# NaN     20000443   130040                                     Mo (1983)
#
#                                     genres  rating     timestamp
# userId
# ...

# %%
del movies_rating_df['index']
movies_rating_df
# Out:
#                                                                                      userId  \
# movieId title                         genres
# 1       Toy Story (1995)              Adventure|Animation|Children|Comedy|Fantasy       3.0
#                                       Adventure|Animation|Children|Comedy|Fantasy       6.0
#                                       Adventure|Animation|Children|Comedy|Fantasy       8.0
#                                       Adventure|Animation|Children|Comedy|Fantasy      10.0
#                                       Adventure|Animation|Children|Comedy|Fantasy      11.0
# ...                                                                                     ...
# 131254  Kein Bund für's Leben (2007)  Comedy                                        79570.0
# 131256  Feuer, Eis & Dosenbier (2002) Comedy                                        79570.0
# 131258  The Pirates (2014)            Adventure                                     28906.0
# ...

# %%
total = back_uo.groupby('movieId')[['userId','rating']].nunique()
below = back_uo.loc[back_uo['rating']<=2.5].groupby('movieId')[['userId','rating']].nunique()
unique_users = back_uo.groupby('userId')[['movieId','title']].nunique()
unique_users
# 138493.0
# Out:
#           movieId  title
# userId
# 1.0           175    175
# 2.0            61     61
# 3.0           187    187
# 4.0            28     28
# 5.0            66     66
# ...           ...    ...
# 138489.0       38     38
# 138490.0      151    151
# 138491.0       22     22
# 138492.0       82     82
# 138493.0      373    373
#
# [138493 rows x 2 columns]

# %%
unique_users['movieId'].mean()
# Out:
# np.float64(144.4135299257002)

# %%
# movie with lowest amount of reviews 
# movie with highest amount of reviews 
movies_rating_df.loc[movies_rating_df['rating']<2].groupby('movieId').size()
movies_rating_df.loc[movies_rating_df['rating']>3].groupby('movieId').size()
# Out:
# movieId
# 1          950
# 2         1348
# 3          973
# 4          393
# 5         1013
#           ...
# 131013       1
# 131060       1
# 131062       1
# 131152       1
# 131172       1
# Length: 17288, dtype: int64

# %%
# not needed
back_uo['genres'] = back_uo['genres'].str.split("|")

# %%
back_uo
# Out:
#              index  movieId                          title  \
# 0                0        1               Toy Story (1995)
# 1                1        1               Toy Story (1995)
# 2                2        1               Toy Story (1995)
# 3                3        1               Toy Story (1995)
# 4                4        1               Toy Story (1995)
# ...            ...      ...                            ...
# 20000792  20000792   131254   Kein Bund für's Leben (2007)
# 20000793  20000793   131256  Feuer, Eis & Dosenbier (2002)
# 20000794  20000794   131258             The Pirates (2014)
# 20000795  20000795   131260            Rentun Ruusu (2001)
# 20000796  20000796   131262               Innocence (2014)
#
#                                                      genres    userId  rating  \
# 0         [Adventure, Animation, Children, Comedy, Fantasy]       3.0     4.0
# 1         [Adventure, Animation, Children, Comedy, Fantasy]       6.0     5.0
# ...

# %%
# back_uo.loc[movies_rating_df['rating']==5 if back_uo['genres'].str.contains('Animation')]
back_uo.loc[(back_uo['rating'] == 4) & (back_uo['genres'].str.contains('Animation'))].groupby('title').size()
# Out:
# title
# $9.99 (2008)                                                11
# 'Twas the Night Before Christmas (1974)                      2
# 101 Dalmatians (One Hundred and One Dalmatians) (1961)    2373
# 101 Dalmatians II: Patch's London Adventure (2003)           1
# 2012: Time for Change (2010)                                 1
#                                                           ...
# Wrinkles (Arrugas) (2011)                                    5
# Yellow Submarine (1968)                                   1322
# You're a Good Man, Charlie Brown (1985)                     11
# Your Friend the Rat (2007)                                   7
# Yu-Gi-Oh! (2004)                                             9
# Length: 789, dtype: int64

# %%
# will be faster when 10's of millions of dataset 
all_genres_gpt = back_uo['genres'].str.split("|").explode().unique()

# %%
all_genres_gpt
# Out:
# array(['Adventure', 'Animation', 'Children', 'Comedy', 'Fantasy',
#        'Romance', 'Drama', 'Action', 'Crime', 'Thriller', 'Horror',
#        'Mystery', 'Sci-Fi', 'IMAX', 'Documentary', 'War', 'Musical',
#        'Western', 'Film-Noir', '(no genres listed)'], dtype=object)

# %%
all_genres = back_uo['genres'].str.split("|").explode()

# %%
all_genres.value_counts()
# Out:
# genres
# Drama                 8858135
# Comedy                7502376
# Action                5614262
# Thriller              5313555
# Adventure             4380393
# Romance               3802100
# Crime                 3298385
# Sci-Fi                3150164
# Fantasy               2111417
# Children              1669270
# Mystery               1557307
# Horror                1482758
# Animation             1140488
# War                   1048639
# Musical                870935
# IMAX                   492367
# Western                423734
# Documentary            244699
# Film-Noir              216697
# (no genres listed)        365
# Name: count, dtype: int64

# %%
# all the genres avaiable 
all_list_genres = sorted(set(
    genre 
    for genres_str in back_uo['genres'].dropna() 
    for genre in genres_str.split("|")
))

# %%
all_list_genres_non = sorted(
    genre 
    for genres_str in back_uo['genres'].dropna() 
    for genre in genres_str.split("|")
)

# %%
for genre in all_list_genres:
    print(f"{genre}: {all_list_genres_non.count(genre)}")
# Out:
# (no genres listed): 365
# Action: 5614262
# Adventure: 4380393
# Animation: 1140488
# Children: 1669270
# Comedy: 7502376
# Crime: 3298385
# Documentary: 244699
# Drama: 8858135
# Fantasy: 2111417
# Film-Noir: 216697
# Horror: 1482758
# IMAX: 492367
# Musical: 870935
# Mystery: 1557307
# Romance: 3802100
# Sci-Fi: 3150164
# Thriller: 5313555
# War: 1048639
# Western: 423734

# %%
import numpy as np
def analyze_row_patterns(sparse_matrix):
    """
    Analyze patterns in each row of a sparse matrix.
    Returns dictionary with various row statistics.
    """
    # Convert to CSR format for efficient row operations
    # stores non xero by row so each row is a user and don't store zero's 
    csr_matrix = sparse_matrix.tocsr()
    
    # Calculate statistics
    row_sums = np.array(csr_matrix.sum(axis=1)).flatten()
    # indptr (index pointer) is array of starting and ending indices in row
    # so we shows each elemnt pointing to start of rows data in mem amd diff gives the difference between each value, 
    # so we get the number of non zero entries 
    row_nonzeros = np.diff(csr_matrix.indptr)  # Number of non-zeros per row
    
    # Calculate means, handling empty rows
    # below gives zeros matrix in same shape as row_sums
    row_means = np.zeros_like(row_sums, dtype=float)
    # makes sure we have no zero ratings which could mess the average up 
    mask = row_nonzeros > 0
    row_means[mask] = row_sums[mask] / row_nonzeros[mask]
    
    return {
        'activity_sum': row_sums,      # Total activity per user
        'interaction_count': row_nonzeros,  # Number of interactions per user
        'average_value': row_means     # Average value per user
    }

# %%
from scipy.sparse import coo_matrix

# NOTE: User and Movie IDs must be zero-indexed and sequential for the sparse matrix!

# 1. Map IDs to Zero-Indexed Indices
# This creates sequential indices starting from 0, which is mandatory for sparse matrices.
user_map = {id: i for i, id in enumerate(ratings_df['userId'].unique())}
movie_map = {id: i for i, id in enumerate(ratings_df['movieId'].unique())}

ratings_df['user_index'] = ratings_df['userId'].map(user_map)
ratings_df['movie_index'] = ratings_df['movieId'].map(movie_map)

# 2. Build the Sparse Matrix Directly
# The data, rows, and columns correspond to the rating, user_index, and movie_index. this is coo matrix way for creating spares matrices 
sparse_matrix = coo_matrix(
    (ratings_df['rating'], (ratings_df['user_index'], ratings_df['movie_index'])),
    shape=(len(user_map), len(movie_map))
)

# 3. Convert to CSR for Analysis (as required by your function)
# csr_matrix_for_analysis = sparse_matrix.tocsr() 

# 4. Now, run your analysis function:
user_stats = analyze_row_patterns(sparse_matrix)

# %%
# from above gets the sparse matrix
import numpy as np
from sklearn.decomposition import TruncatedSVD
# truncatedsvd is algorithm for dimension reduction and matrix factorisation for large sparse data
# n_components is a hyperparameter which defines number latent factors i want to extract, 
#   this means each user with vector of 100 latent factors and each movie with vector of 100 latent factors and random state choosen
svd = TruncatedSVD(n_components=200, random_state=42)
# the fit_tranform this performs matric factorization and trains the model on user-item matrix to learn latent factors 
reduced_matrix = svd.fit_transform(sparse_matrix)
# the user matrix is in reduced_matrix and the item matrix is stored in svd object (svd.components_)

# predicited is U * V_T
predicted_ratings = np.dot(reduced_matrix, svd.components_)

idx_to_user_id = {i: id for id, i in user_map.items()}
idx_to_movie_id = {i: id for id, i in movie_map.items()}

# matrix to df
predicted_ratings_df = pd.DataFrame(
    predicted_ratings,
    index=list(idx_to_user_id.values()),   # User IDs as rows
    columns=list(idx_to_movie_id.values()) # Movie IDs as columns
)

predicted_ratings_df.index.name = 'userId'
predicted_ratings_df.columns.name = 'movieId'

# %%
predicted_ratings_df
# Out:
# movieId    2         29        32        47        50        112       151     \
# userId
# 1        3.545469  1.310797  3.504291  3.453971  3.326398  0.949691  0.919139
# 2        0.064224  0.037603  0.033701  0.079744  0.003584 -0.220365  0.707274
# 3        0.860493  0.336747  4.283215 -0.105345  4.945352  0.412853 -0.019236
# 4        0.729948  0.185875  0.896834 -0.205875 -0.025102  0.274113 -0.248581
# 5        3.069094 -0.030366 -0.040001 -0.051252 -0.492143 -0.202997  0.271098
# ...           ...       ...       ...       ...       ...       ...       ...
# 138489   0.063120  0.657220  0.180073  0.024030  4.490556 -0.105956 -0.152114
# 138490   0.089992  0.467708  4.932729 -0.454553 -0.139256 -0.003280  1.093778
# 138491   0.034387  0.014050  0.011927 -0.089425  0.015979 -0.049056  0.071842
# 138492  -0.072984 -0.244490 -0.260672  0.209853  0.274746  0.168781 -0.133078
# 138493   1.830104  1.220545  0.007335  0.336391  0.149433  0.406026  1.301289
#
# ...

# %%
def  recomanded_movies(target_user_id, rating_df, predicted_df, full_movie_genre_df, top_n =10):
    rated_movies = rating_df[rating_df["userId"]==target_user_id]['movieID'].tolist()

    # get the predicted ratings 
    user_predictions = predicted_df.loc[target_user_id].sort_values(ascending = False)
    # get unwatched movies from predictions 
    user_predictions = user_predictions[~user_predictions.index.isin(rated_movies)]

    top_movies = user_predictions.head(top_n)
    # gets the full movies where the movieId column is in the top movies index list
    recom_df = full_movie_genre_df[full_movie_genre_df["movieId"].isin(top_movies.index)]

    # as we set index as movieid which is the same as top movie we can join them and just add prediction on to it 
    recom_df = recom_df.set_index("movieID")
    recom_df["predicitons"] = top_movies

    return recom_df

# %%
ratings_df
# Out:
#           userId  movieId  rating   timestamp  user_index  movie_index
# 0              1        2     3.5  1112486027           0            0
# 1              1       29     3.5  1112484676           0            1
# 2              1       32     3.5  1112484819           0            2
# 3              1       47     3.5  1112484727           0            3
# 4              1       50     3.5  1112484580           0            4
# ...          ...      ...     ...         ...         ...          ...
# 20000258  138493    68954     4.5  1258126920      138492         1814
# 20000259  138493    69526     4.5  1259865108      138492         1037
# 20000260  138493    69644     3.0  1260209457      138492         3950
# 20000261  138493    70286     5.0  1258126944      138492         1818
# 20000262  138493    71619     2.5  1255811136      138492         4010
#
# [20000263 rows x 6 columns]

# %%
links_df = links_df.reset_index()
links_df.set_index("movieId", inplace=True)
links_df = links_df[links_df['tmdbId'].notna()]
links_df['tmdbId']= links_df.tmdbId.astype(int)
del links_df['index']
links_df
# Out:
#           imdbId  tmdbId
# movieId
# 1         114709     862
# 2         113497    8844
# 3         113228   15602
# 4         114885   31357
# 5         113041   11862
# ...          ...     ...
# 131254    466713    4436
# 131256    277703    9274
# 131258   3485166  285213
# 131260    249110   32099
# 131262   1724965  286971
#
# [27026 rows x 2 columns]

# %%
full_movie_df = pd.merge(movie_df, links_df, how="left", on="movieId")
cols = ["tmdbId", "imdbId"]
full_movie_df[cols] = full_movie_df[cols].astype("Int64")
full_movie_df
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres   imdbId  tmdbId
# 0      Adventure|Animation|Children|Comedy|Fantasy   114709     862
# 1                       Adventure|Children|Fantasy   113497    8844
# 2                                   Comedy|Romance   113228   15602
# 3                             Comedy|Drama|Romance   114885   31357
# ...

# %%
recom_df = full_movie_df[full_movie_df["movieId"].isin(top_movies.index)]
recom_df = recom_df.set_index("movieId")
recom_df["predicitons"] = top_movies

# %%
recom_df["predicitons"] = top_movies

# %%
top_movies
# Out:
# movieId
# 260     5.197535
# 1210    4.838841
# 110     4.323708
# 1196    4.258922
# 480     4.146946
# 589     3.984717
# 1270    3.272024
# 2858    3.019547
# 1214    2.565329
# 1200    2.202863
# Name: 2, dtype: float64

# %%
recom_df
# Out:
#                                                      title  \
# movieId
# 110                                      Braveheart (1995)
# 260              Star Wars: Episode IV - A New Hope (1977)
# 480                                   Jurassic Park (1993)
# 589                      Terminator 2: Judgment Day (1991)
# 1196     Star Wars: Episode V - The Empire Strikes Back...
# 1200                                         Aliens (1986)
# 1210     Star Wars: Episode VI - Return of the Jedi (1983)
# 1214                                          Alien (1979)
# 1270                             Back to the Future (1985)
# 2858                                American Beauty (1999)
#
#                                    genres  imdbId  tmdbId predicitons
# movieId
# 110                      Action|Drama|War  112573     197    4.323708
# 260               Action|Adventure|Sci-Fi   76759      11    5.197535
# 480      Action|Adventure|Sci-Fi|Thriller  107290     329    4.146946
# ...

# %%
def recommend_movies_svd(target_user_id, predicted_df, original_ratings_df, movie_metadata_df, top_n=10):
    
    # 1. Get all movies already rated by the target user
    rated_movies = original_ratings_df[original_ratings_df['userId'] == target_user_id]['movieId'].tolist()

    # 2. Get the row of predicted ratings for the target user
    user_predictions = predicted_df.loc[target_user_id].sort_values(ascending=False)

    # 3. Filter out movies the user has already rated
    # gets the user predictions where the rated movies hasn't been watched as the ~ is not and checks in index if rated movie id is not in there
    unseen_predictions = user_predictions[~user_predictions.index.isin(rated_movies)]

    # 4. Get the top N recommended movie IDs
    top_recommendations = unseen_predictions.head(top_n)
    
    # 5. Merge with movie metadata to get titles and genres
    rec_df = movie_metadata_df[
        movie_metadata_df['movieId'].isin(top_recommendations.index)
    ]
    
    # Join with predicted ratings and display
    rec_df = rec_df.set_index('movieId')
    rec_df['Predicted_Rating'] = top_recommendations
    
    # Sort by the predicted rating and return the final list
    return rec_df.sort_values('Predicted_Rating', ascending=False)[['title', 'genres', 'Predicted_Rating']]

# %%
original_user_ids = list(user_map.keys())
user_stats_df = pd.DataFrame({
    'interaction_count': user_stats['interaction_count'],
    'average_rating': user_stats['average_value']
}, index=original_user_ids)

# Analyze the distribution of these new metrics
user_stats_df.describe()
# Out:
#        interaction_count  average_rating
# count      138493.000000   138493.000000
# mean          144.413530        3.627209
# std           230.267257        0.443030
# min            20.000000        0.500000
# 25%            35.000000        3.369478
# 50%            68.000000        3.653846
# 75%           155.000000        3.923077
# max          9254.000000        5.000000

# %%
user_stats_df
# Out:
#         interaction_count  average_rating
# 1                     175        3.742857
# 2                      61        4.000000
# 3                     187        4.122995
# 4                      28        3.571429
# 5                      66        4.272727
# ...                   ...             ...
# 138489                 38        3.986842
# 138490                151        3.556291
# 138491                 22        2.681818
# 138492                 82        4.097561
# 138493                373        4.172922
#
# [138493 rows x 2 columns]

# %%
movies_rating_df
# Out:
#                                                                                      userId  \
# movieId title                         genres
# 1       Toy Story (1995)              Adventure|Animation|Children|Comedy|Fantasy       3.0
#                                       Adventure|Animation|Children|Comedy|Fantasy       6.0
#                                       Adventure|Animation|Children|Comedy|Fantasy       8.0
#                                       Adventure|Animation|Children|Comedy|Fantasy      10.0
#                                       Adventure|Animation|Children|Comedy|Fantasy      11.0
# ...                                                                                     ...
# 131254  Kein Bund für's Leben (2007)  Comedy                                        79570.0
# 131256  Feuer, Eis & Dosenbier (2002) Comedy                                        79570.0
# 131258  The Pirates (2014)            Adventure                                     28906.0
# ...

# %%
from fuzzywuzzy import fuzz 
def find_best_match(movielens_title, tmdb_titles_list):
    """
    Finds the best matching TMDb title for a given MovieLens title.
    """
    best_score = 0
    best_match = None
    
    for tmdb_title in tmdb_titles_list:
        # Calculate the Token Set Ratio (robust against missing/extra words)
        score = fuzz.token_set_ratio(movielens_title.lower(), tmdb_title.lower())
        
        if score > best_score:
            best_score = score
            best_match = tmdb_title
            
    # Set a minimum acceptable threshold (e.g., 90)
    if best_score >= 90:
        return best_match, best_score
    else:
        return None, best_score
    
def clean_title(title):
    return title.split(' (')[0].lower()

# %%
# apply df and then 
import requests
def get_tmdb_overview_concurrent(movie_id):
    url = f"https://api.themoviedb.org/3/movie/{movie_id}?language=en-US"
    # url = "https://api.themoviedb.org/3/movie/1233413?language=en-US"
    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlN2ZlMzU1YjBjZGVhMGI1ZDYxYzdjN2IzMDQ1ZGVhMSIsIm5iZiI6MTc1MTI5OTQwNy4wNDgsInN1YiI6IjY4NjJiNTRmNmI2OTI5MTJiYzg5MmEwMSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.lWKH5j6asUrcwXFPTSmqOH1Bq4o1ciMOkvYTZtPLL3s"
    }
    try:
        response = requests.get(url, headers=headers)
        result = response.json()
        return result.get("overview")
    except requests.exceptions.RequestException as e:
        # Log the error but continue
        print(f"Error fetching ID {movie_id}: {e}") 
        return None

# %%
from concurrent.futures import ThreadPoolExecutor
from tqdm import tqdm
MAX_WORKERS = 10


valid_tmdb_ids = full_movie_df['tmdbId'].dropna().unique()

# 2. Use a dictionary to store results keyed by tmdbId for quick assignment
overview_map = {}

# Use ThreadPoolExecutor to run the function concurrently
with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
    # Map the function to the list of unique IDs and track progress
    results = list(tqdm(
        executor.map(get_tmdb_overview_concurrent, valid_tmdb_ids),
        total=len(valid_tmdb_ids),
        desc="Fetching TMDb Overviews"
    ))

# 3. Create the mapping dictionary
overview_map = dict(zip(valid_tmdb_ids, results))

# 4. Apply the pre-fetched results back to the DataFrame
# using the tmdbid we map the values from overview map to overview 
full_movie_df["overview"] = full_movie_df["tmdbId"].map(overview_map)
# Out:
# Fetching TMDb Overviews: 100%|██████████| 27008/27008 [12:21<00:00, 36.43it/s]

# %%
full_movie_df.to_csv("./full_movie_df_ow.csv", index=None)

# %%
full_movie_df
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres   imdbId  tmdbId  \
# 0      Adventure|Animation|Children|Comedy|Fantasy   114709     862
# 1                       Adventure|Children|Fantasy   113497    8844
# 2                                   Comedy|Romance   113228   15602
# 3                             Comedy|Drama|Romance   114885   31357
# ...

# %%
full_movie_df = pd.read_csv("./full_movie_df_ow.csv", index_col=False)

# %%
full_movie_df.sort_index(inplace=True)
full_movie_df
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres     imdbId    tmdbId  \
# 0      Adventure|Animation|Children|Comedy|Fantasy   114709.0     862.0
# 1                       Adventure|Children|Fantasy   113497.0    8844.0
# 2                                   Comedy|Romance   113228.0   15602.0
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# tf (term freuqnecy), how often word appears in doc 
# idf (inverse document frequency), how rare word is across all docs 
vectorizer = TfidfVectorizer(
    stop_words='english',  # Automatically remove common English words
    ngram_range=(1, 6),    # Include unigrams (single words) and bigrams (two-word phrases) so tw oword phrases (space adventure) score together 
    min_df=6               # Ignore terms that appear in less than 5 documents, word or phrase must appear at least in 5 different documents
                            # rare words are ignored
)
tfidf_matrix = vectorizer.fit_transform(   #fit gets all vocab that meet criteria and transform convers doc into vector of 
    full_movie_df["overview"].fillna("")  #tf-idf scores so rows = movies | columns = words/bigrams | values = tf-idf weight 
)
print(tfidf_matrix.shape)
tfidf_matrix_32 = tfidf_matrix.astype('float32')
# Out:
# (27278, 18654)

# %%
from sklearn.metrics.pairwise import linear_kernel
# gets the dot product of the tf-idf matrix with its transpose. So rows is movies, columns is movies and values is similarity score 
cosine_sim = linear_kernel(tfidf_matrix_32)

print("Calculation complete. Shape:", cosine_sim.shape)
# Out:
# Calculation complete. Shape: (27278, 27278)

# %%
print("Calculation complete. Shape:", cosine_sim.shape)
# Out:
# Calculation complete. Shape: (27278, 27278)

# %%
full_movie_df['genres'] = full_movie_df['genres'].str.split("|")
full_movie_genre_split = full_movie_df.copy(deep=True)

# %%
def genre_check(movie_genre_string, required_gener, min_count=3):
    if pd.isna(movie_genre_string) or pd.isna(required_gener):
        return False
    movie_genre_string= set(movie_genre_string.split('|'))
    return len(required_gener.intersection(movie_genre_string)) >= min_count

# %%
def find_cosine_row(name):
    movie_row = full_movie_df[full_movie_df['title']=='Toy Story (1995)']
    position = movie_row.index.values.astype(int)[0]
    items = enumerate(cosine_sim[position])
    top_sims = sorted(items, key = lambda x:x[1], reverse=True)
    # top_10_sim = top_sims[1:11]
    movies_id_use = [item[0 ]for item in top_sims]
    all_similar_movies =  full_movie_df.iloc[movies_id_use]
    main_movie_genre = movie_row['genres'].str.split("|").explode().unique()
    genre_pattern = set(main_movie_genre.tolist())
    min_genre_match = len(genre_pattern) if len(genre_pattern) <= 2 else 3
    genre_filtered_movies = all_similar_movies[all_similar_movies.apply(lambda x: genre_check(x['genres'], genre_pattern, min_genre_match), axis=1)]
    # print(full_movie_df[main_movie_genre.isin(all_similar_movies['genre'])])
    # need to check if genre in list above 
    # movie_metadata_df['movieId'].isin(top_recommendations.index)
    return genre_filtered_movies

# %%
def top_words():
    position = full_movie_df[full_movie_df['title']=='Toy Story (1995)'].index.values.astype(int)[0]
    feature_names = vectorizer.get_feature_names_out()
    feature_scores = tfidf_matrix[position].toarray().flatten()

    # 4. Pair features with scores and sort
    sorted_features = sorted(
        zip(feature_names, feature_scores),
        key=lambda x: x[1], 
        reverse=True
    )
    
    print(f"\nTop 10Keywords for 'toy story ':")
    for feature, score in sorted_features[:10]:
        print(f"  - {feature}: {score:.4f}")

# %%
x = (find_cosine_row(1))

# %%
x
# Out:
#        movieId                                              title  \
# 0            1                                   Toy Story (1995)
# 15401    78499                                 Toy Story 3 (2010)
# 3027      3114                                 Toy Story 2 (1999)
# 24460   115879                  Toy Story Toons: Small Fry (2011)
# 1957      2041                                   Condorman (1981)
# ...        ...                                                ...
# 27221   131092  Mickey, Donald, Goofy: The Three Musketeers (2...
# 27224   131098                                Saving Santa (2013)
# 27226   131102       Lucky Luke: The Ballad of the Daltons (1978)
# 27235   131120                             Superstar Goofy (1991)
# 27270   131248                              Brother Bear 2 (2006)
#
#                                                  genres     imdbId    tmdbId  \
# 0           Adventure|Animation|Children|Comedy|Fantasy   114709.0     862.0
# ...

# %%
top_words()
# Out:
# Top 10Keywords for 'toy story ':
#   - buzz: 0.4861
#   - woody: 0.4790
#   - andy: 0.4221
#   - live happily: 0.1718
#   - aside differences: 0.1698
#   - toys: 0.1465
#   - aside: 0.1454
#   - afraid: 0.1443
#   - differences: 0.1319
#   - happily: 0.1304

# %%
tag_df = pd.merge(genome_score, genome_tag, how='inner', on='tagId' )

# %%
tagdf_capped = tag_df.loc[tag_df['relevance'] >= 0.8]

# %%
tagdf_capped.set_index('movieId', inplace=True)

# %%
movie_id_list = tagdf_capped.index.unique().to_list()
tag_id_id_list = tagdf_capped['tagId'].tolist()

# %%
tag_df_sorted = tagdf_capped.sort_values(by=['movieId', 'relevance'], ascending=[True,False])
tag_df_sorted
# Out:
#         movieId  tagId  relevance                 tag
# 0             1   1036    0.99925                toys
# 1             1    244    0.99850  computer animation
# 2             1    786    0.99600     pixar animation
# 3             1    589    0.99075     kids and family
# 4             1     64    0.98575           animation
# ...         ...    ...        ...                 ...
# 103047   131170    299    0.83325             destiny
# 103048   131170    302    0.82525            dialogue
# 103049   131170    999    0.81525            suspense
# 103050   131170    998    0.80550            survival
# 103051   131170    419    0.80275              future
#
# [103052 rows x 4 columns]

# %%
# enter movie id then find top 5 tags and with them find movies which also has them and then cross referrence with other list

# %%
movie_tag_sets = tag_df_sorted.groupby('movieId')['tagId'].apply(set).reset_index(name='tag_set')
movie_tag_sets
# Out:
#        movieId                                            tag_set
# 0            1  {1036, 785, 786, 278, 536, 412, 29, 414, 415, ...
# 1            2  {584, 203, 204, 588, 1074, 374, 951, 377, 604,...
# 2            3                               {451, 901, 902, 230}
# 3            4                                   {201, 1116, 439}
# 4            5          {451, 901, 230, 902, 808, 1102, 374, 383}
# ...        ...                                                ...
# 10155   130578                                 {841, 82, 19, 447}
# 10156   130840           {864, 614, 742, 522, 846, 212, 538, 863}
# 10157   131013           {417, 833, 230, 967, 813, 272, 979, 505}
# 10158   131168  {128, 1121, 1091, 581, 270, 176, 212, 697, 733...
# 10159   131170  {777, 787, 788, 789, 803, 419, 299, 302, 52, 5...
#
# [10160 rows x 2 columns]

# %%
# have tags for each movie now 
full_movie_df = full_movie_df.merge(movie_tag_sets, on='movieId', how='left')

# %%
movie_tags = tag_df_sorted.loc[tag_df_sorted.movieId==1].head(2)

# %%
movie_tags_list=sorted(movie_tags["tagId"].tolist())
required_movie_tag_set = set(movie_tags_list)

# %%
# can swap full_movie_df with x from genre matching but not all genre matching has tags 
matching_movies = full_movie_df[full_movie_df["tag_set"].apply(lambda x: pd.notna(x) and required_movie_tag_set.issubset(x))]

# %%
matching_movies
# Out:
#        movieId                                   title  \
# 0            1                        Toy Story (1995)
# 15401    78499                      Toy Story 3 (2010)
# 3027      3114                      Toy Story 2 (1999)
# 1836      1920                   Small Soldiers (1998)
# 14765    73854  Rudolph, the Red-Nosed Reindeer (1964)
# 21981   106022              Toy Story of Terror (2013)
# 2270      2355                    Bug's Life, A (1998)
# 4790      4886                   Monsters, Inc. (2001)
# 6271      6377                     Finding Nemo (2003)
# 22763   108932                   The Lego Movie (2014)
#
#                                                   genres     imdbId    tmdbId  \
# 0            Adventure|Animation|Children|Comedy|Fantasy   114709.0     862.0
# 15401   Adventure|Animation|Children|Comedy|Fantasy|IMAX   435761.0   10193.0
# 3027         Adventure|Animation|Children|Comedy|Fantasy   120363.0     863.0
# ...
